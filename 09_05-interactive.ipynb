# %%
# %matplotlib notebook

# %%
import pandas as pd
df = pd.read_csv('lnkd.csv', parse_dates=['Date'], index_col='Date')
df[['Close', 'Volume']].plot(subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11084ba20>,
# ...
#       dtype=object)
